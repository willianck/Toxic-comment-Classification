# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.naive_bayes import BernoulliNB, GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, f1_score, auc, roc_auc_score, confusion_matrix
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('drive/MyDrive/CS247/train_emb.pkl', 'rb') as fid:
     train_data= pickle.load(fid)

with open('drive/MyDrive/CS247/val_emb.pkl', 'rb') as fid:
     valid_data= pickle.load(fid)

with open('drive/MyDrive/CS247/test_emb.pkl', 'rb') as fid:
     test_data= pickle.load(fid)

with open('drive/MyDrive/CS247/train_data.pkl', 'rb') as fid:
     comment_train_data= pickle.load(fid)

with open('drive/MyDrive/CS247/test_data.pkl', 'rb') as fid:
     comment_test_data= pickle.load(fid)

# %%
## GETTING LIST FROM THE LOADED DATA
train_data = list(train_data)
valid_data = list(valid_data)
test_data = list(test_data)

# %%
## GENERATE PANDAS DATAFRAMES
train_df = pd.DataFrame(train_data)
valid_df = pd.DataFrame(valid_data)
test_df = pd.DataFrame(test_data)

train_df.head(10)
# Out:
#                                                    0  1  2  3  4  5  6
# 0  [0.2640609774222722, -0.4600453673251684, 0.03...  0  0  0  0  0  0
# 1  [-0.04011194184194853, -0.5940424284618303, -0...  1  0  1  1  0  0
# 2  [0.3461568960768919, -0.5365164560302055, 0.11...  0  0  0  0  0  0
# 3  [0.22332606270303804, -0.3382712470869757, 0.0...  0  0  0  0  0  0
# 4  [0.325931273794575, -0.20956713868307272, 0.14...  0  0  0  0  0  0
# 5  [1.183401224224616, -0.5341410448336582, 0.360...  0  0  0  0  0  0
# 6  [0.5360300184813922, -0.4562388682939364, 0.49...  0  0  0  0  0  0
# 7  [0.5236535839338992, -0.8367316260505495, 0.75...  0  0  0  0  0  0
# 8  [0.27385612539126286, -0.273880081400397, 0.08...  0  0  0  0  0  0
# 9  [0.3366081304893847, -0.2594793260630475, 0.01...  0  0  0  0  0  0

# %%
## CHECK DATA STRUCTURE

comment_train_data.head(1)
# Out:
#                       id                                       comment_text  \
# 112366  591e7ceac4e56588  Would agree. While it's clear that GQ is ripe ...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate  \
# 112366      0             0        0       0       0              0
#
#                     Target                                    comment_text_wp  \
# 112366  [0, 0, 0, 0, 0, 0]  would agree clear gq ripe trek references refe...
#
#                                          comment_tokenize  \
# 112366  [would, agree, clear, gq, ripe, trek, referenc...
#
#                                                   comment
# 112366  would agree while it is clear that gq is ripe ...

# %%
## CHECK HOW MANY EXAMPLES PER CLASS
toxic = valid_df[1].sum(0)
severe_toxic = valid_df[2].sum(0)
obscene = valid_df[3].sum(0)
threat = valid_df[4].sum(0)
insult = valid_df[5].sum(0)
identity_hate = valid_df[6].sum(0)

print("Toxic examples: ", toxic)
print("Severe toxic examples: ", severe_toxic)
print("Obscene examples: ", obscene)
print("Threat examples: ", threat)
print("Insult examples: ", insult)
print("Identity hate examples: ", identity_hate)
# Out:
# Toxic examples:  5397
# Severe toxic examples:  557
# Obscene examples:  2811
# Threat examples:  3007
# Insult examples:  164
# Identity hate examples:  497

# %%
## CLASSIFIERS

def basic_classifier_tester(X_train,Y_train,X_test,Y_test,class_weight=None,use_gaussian=False):
    f1 = []
    report_scores = {}
    if(not use_gaussian):
      classifiers = [LogisticRegression(max_iter=200,class_weight=class_weight), BernoulliNB()]
    else:
      classifiers = [LogisticRegression(max_iter=200,class_weight=class_weight), GaussianNB()]
    for classifier in (classifiers):
        classifier.fit(X_train, Y_train)
        predictions = classifier.predict(X_test)
        f1.append(f1_score(Y_test, predictions))
        report = classification_report(Y_test, predictions)
        report_scores[classifier.__class__.__name__] = report
        print(classifier.__class__.__name__ + ":")
        print(report)
        print("Confusion Matrix")
        print(confusion_matrix(Y_test, predictions))
        print('------------------------------------------------------')
    return report_scores, f1

## USEFUL FUNCTIONS

def df_to_array(df):
  df_list = []
  for i in range(len(df[0])):
    df_list.append(df[0][i])
  df_list = np.array(df_list)
  df_list.reshape(len(df[0][0]),-1)
  return df_list

def normalize_data(data):
  eps = 1e-5
  N = data.shape[0]
  mu = 1/N*np.sum(data,axis=0)
  sigma = 1/N*np.sum((data-mu)**2,axis=0)
  normalized_data = (data-mu)/(np.sqrt(sigma+eps))
  return normalized_data

# %%
## DEFINE THE SETS
X_train = df_to_array(train_df)
X_valid = df_to_array(valid_df)
X_test = df_to_array(test_df)

print("Train shape: ", X_train.shape)
print("Valid shape: ", X_valid.shape)
print("Test shape: ", X_test.shape)
# Out:
# Train shape:  (103683, 100)
# Valid shape:  (55832, 100)
# Test shape:  (63542, 100)

# %%
## DEFINE THE LABELS FOR "TOXIC"
y_train_toxic = train_df[1]
y_valid_toxic = valid_df[1]
y_test_toxic = test_df[1]

# %%
toxic_scores, f1_toxic = basic_classifier_tester(X_train,y_train_toxic,X_valid,y_valid_toxic)
# Out:
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.98      0.42      0.59     50435
#            1       0.14      0.92      0.25      5397
#
#     accuracy                           0.47     55832
#    macro avg       0.56      0.67      0.42     55832
# weighted avg       0.90      0.47      0.56     55832
#
# Confusion Matrix
# [[21277 29158]
#  [  454  4943]]
# ------------------------------------------------------
# BernoulliNB:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     50435
#            1       0.52      0.34      0.41      5397
#
#     accuracy                           0.91     55832
#    macro avg       0.73      0.65      0.68     55832
# weighted avg       0.89      0.91      0.90     55832
#
# Confusion Matrix
# [[48746  1689]
#  [ 3556  1841]]
# ------------------------------------------------------

# %%
## DEFINE THE LABELS FOR "SEVERE TOXIC"
y_train_sevtoxic = train_df[2]
y_valid_sevtoxic = valid_df[2]
y_test_sevtoxic = test_df[2]

# %%
sev_toxic_scores, f1_sevtoxic = basic_classifier_tester(X_train,y_train_sevtoxic,X_valid,y_valid_sevtoxic)
# Out:
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     55275
#            1       0.06      0.03      0.04       557
#
#     accuracy                           0.99     55832
#    macro avg       0.52      0.51      0.52     55832
# weighted avg       0.98      0.99      0.98     55832
#
# Confusion Matrix
# [[54985   290]
#  [  539    18]]
# ------------------------------------------------------
# BernoulliNB:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     55275
#            1       0.36      0.15      0.21       557
#
#     accuracy                           0.99     55832
#    macro avg       0.68      0.57      0.60     55832
# weighted avg       0.99      0.99      0.99     55832
#
# Confusion Matrix
# [[55124   151]
#  [  472    85]]
# ------------------------------------------------------

# %%
## DEFINE THE LABELS FOR "OBSCENE"
y_train_obscene = train_df[3]
y_valid_obscene = valid_df[3]
y_test_obscene = test_df[3]

# %%
obscene_scores, f1_obscene = basic_classifier_tester(X_train,y_train_obscene,X_valid,y_valid_obscene)
# Out:
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.99      0.53      0.69     53021
#            1       0.09      0.86      0.16      2811
#
#     accuracy                           0.55     55832
#    macro avg       0.54      0.70      0.43     55832
# weighted avg       0.94      0.55      0.66     55832
#
# Confusion Matrix
# [[28236 24785]
#  [  396  2415]]
# ------------------------------------------------------
# BernoulliNB:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     53021
#            1       0.53      0.21      0.30      2811
#
#     accuracy                           0.95     55832
#    macro avg       0.74      0.60      0.64     55832
# weighted avg       0.94      0.95      0.94     55832
#
# Confusion Matrix
# [[52494   527]
#  [ 2227   584]]
# ------------------------------------------------------

# %%
## DEFINE THE LABELS FOR "THREAT"
y_train_threat = train_df[4]
y_valid_threat = valid_df[4]
y_test_threat = test_df[4]

# %%
threat_scores, f1_threat = basic_classifier_tester(X_train,y_train_threat,X_valid,y_valid_threat)
# Out:
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.99      0.43      0.59     52825
#            1       0.08      0.93      0.15      3007
#
#     accuracy                           0.45     55832
#    macro avg       0.54      0.68      0.37     55832
# weighted avg       0.94      0.45      0.57     55832
#
# Confusion Matrix
# [[22458 30367]
#  [  225  2782]]
# ------------------------------------------------------
# BernoulliNB:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     52825
#            1       0.55      0.24      0.34      3007
#
#     accuracy                           0.95     55832
#    macro avg       0.75      0.62      0.66     55832
# weighted avg       0.94      0.95      0.94     55832
#
# Confusion Matrix
# [[52226   599]
#  [ 2275   732]]
# ------------------------------------------------------

# %%
## DEFINE THE LABELS FOR "INSULT"
y_train_insult = train_df[5]
y_valid_insult = valid_df[5]
y_test_insult = test_df[5]

# %%
insult_scores, f1_insult = basic_classifier_tester(X_train,y_train_insult,X_valid,y_valid_insult)
# Out:
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     55668
#            1       0.02      0.23      0.04       164
#
#     accuracy                           0.97     55832
#    macro avg       0.51      0.60      0.51     55832
# weighted avg       0.99      0.97      0.98     55832
#
# Confusion Matrix
# [[54099  1569]
#  [  126    38]]
# ------------------------------------------------------
# BernoulliNB:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     55668
#            1       0.06      0.07      0.07       164
#
#     accuracy                           0.99     55832
#    macro avg       0.53      0.53      0.53     55832
# weighted avg       0.99      0.99      0.99     55832
#
# Confusion Matrix
# [[55488   180]
#  [  152    12]]
# ------------------------------------------------------

# %%
## DEFINE THE LABELS FOR "IDENTITY HATE"
y_train_iden_hate = train_df[6]
y_valid_iden_hate = valid_df[6]
y_test_iden_hate = test_df[6]

# %%
identity_hate_scores, f1_iden_hate = basic_classifier_tester(X_train,y_train_iden_hate,X_valid,y_valid_iden_hate)
# Out:
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97     55335
#            1       0.03      0.18      0.06       497
#
#     accuracy                           0.95     55832
#    macro avg       0.51      0.57      0.52     55832
# weighted avg       0.98      0.95      0.96     55832
#
# Confusion Matrix
# [[52819  2516]
#  [  407    90]]
# ------------------------------------------------------
# BernoulliNB:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     55335
#            1       0.14      0.15      0.14       497
#
#     accuracy                           0.98     55832
#    macro avg       0.56      0.57      0.57     55832
# weighted avg       0.98      0.98      0.98     55832
#
# Confusion Matrix
# [[54857   478]
#  [  421    76]]
# ------------------------------------------------------

# %%
## AVERAGE F1 SCORES

n_classes = 6
avg_LR = (f1_toxic[0]+f1_sevtoxic[0]+f1_obscene[0]+f1_threat[0]+f1_insult[0]+f1_iden_hate[0])/n_classes
avg_NB = (f1_toxic[1]+f1_sevtoxic[1]+f1_obscene[1]+f1_threat[1]+f1_insult[1]+f1_iden_hate[1])/n_classes

print("F1 score LR: ", avg_LR)
print("F1 score NB: ", avg_NB)
# Out:
# F1 score LR:  0.1179435551697302
# F1 score NB:  0.24569370507222302

# %% [markdown]
# ### Can we do better on class imbalance: LR with weights and GaussianNB with normalized data

# %%
## CHECK CLASS DISTRIBUTION

d = {1:"Toxic",2:"Severe Toxic",3:"Obscene",4:"Threat",5:"Insult",6:"Identity hate"}

for k in d.keys():
  print(d[k] + ": ")
  print(train_df[k].value_counts()/train_df.shape[0])
  print("----------------------")
# Out:
# Toxic:
# 0    0.904546
# 1    0.095454
# Name: 1, dtype: float64
# ----------------------
# Severe Toxic:
# 0    0.989989
# 1    0.010011
# Name: 2, dtype: float64
# ----------------------
# Obscene:
# 0    0.95114
# 1    0.04886
# Name: 3, dtype: float64
# ----------------------
# Threat:
# 0    0.947513
# 1    0.052487
# Name: 4, dtype: float64
# ----------------------
# Insult:
# 0    0.996972
# 1    0.003028
# Name: 5, dtype: float64
# ----------------------
# Identity hate:
# 0    0.991243
# 1    0.008757
# Name: 6, dtype: float64
# ----------------------

# %%
## DEFINE WEIGHTS TO PASS TO LOGISTIC REGRESSION

w_toxic = {0:10, 1:90}
w_sev_toxic = {0:1, 1:99}
w_obscene = {0:5, 1:95}
w_threat = {0:5, 1:95}
w_insult = {0:0.3, 1:99.7}
w_iden_hate = {0:0.8, 1:99.2}

weights = [w_toxic,w_sev_toxic,w_obscene,w_threat,w_insult,w_iden_hate]

# %%
## NORMALIZE THE DATASETS FOR THE GAUSSIANNB

X_train_norm = normalize_data(X_train)
X_valid_norm = normalize_data(X_valid)
X_test_norm = normalize_data(X_test)

# %%
## USE THE WEIGHTED LR AND GAUSSIANNB

y_train = [y_train_toxic,y_train_sevtoxic,y_train_obscene,y_train_threat,y_train_insult,y_train_iden_hate]
y_valid = [y_valid_toxic,y_valid_sevtoxic,y_valid_obscene,y_valid_threat,y_valid_insult,y_valid_iden_hate]
y_test = [y_test_toxic,y_test_sevtoxic,y_test_obscene,y_test_threat,y_test_insult,y_test_iden_hate]

use_gaussian = True
final_scores = []
final_f1 = []

for i in range(len(y_train)):
  print(">>>>>>>>>>>>>> ", d[i+1])
  w = weights[i]
  scores, f1 = basic_classifier_tester(X_train_norm,y_train[i],X_valid_norm,y_valid[i],w,use_gaussian)
  final_scores.append(scores)
  final_f1.append(f1)
# Out:
# >>>>>>>>>>>>>>  Toxic
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87     50435
#            1       0.24      0.56      0.34      5397
#
#     accuracy                           0.79     55832
#    macro avg       0.59      0.69      0.61     55832
# weighted avg       0.88      0.79      0.82     55832
#
# Confusion Matrix
# [[40966  9469]
#  [ 2354  3043]]
# ------------------------------------------------------
# GaussianNB:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     50435
#            1       0.37      0.37      0.37      5397
#
#     accuracy                           0.88     55832
#    macro avg       0.65      0.65      0.65     55832
# weighted avg       0.88      0.88      0.88     55832
#
# Confusion Matrix
# [[47055  3380]
#  [ 3374  2023]]
# ------------------------------------------------------
# >>>>>>>>>>>>>>  Severe Toxic
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93     55275
#            1       0.06      0.72      0.10       557
#
#     accuracy                           0.88     55832
#    macro avg       0.53      0.80      0.52     55832
# weighted avg       0.99      0.88      0.93     55832
#
# Confusion Matrix
# [[48621  6654]
#  [  158   399]]
# ------------------------------------------------------
# GaussianNB:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97     55275
#            1       0.09      0.46      0.15       557
#
#     accuracy                           0.95     55832
#    macro avg       0.54      0.71      0.56     55832
# weighted avg       0.99      0.95      0.96     55832
#
# Confusion Matrix
# [[52575  2700]
#  [  299   258]]
# ------------------------------------------------------
# >>>>>>>>>>>>>>  Obscene
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90     53021
#            1       0.15      0.50      0.23      2811
#
#     accuracy                           0.83     55832
#    macro avg       0.56      0.67      0.57     55832
# weighted avg       0.93      0.83      0.87     55832
#
# Confusion Matrix
# [[44984  8037]
#  [ 1410  1401]]
# ------------------------------------------------------
# GaussianNB:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96     53021
#            1       0.30      0.36      0.33      2811
#
#     accuracy                           0.93     55832
#    macro avg       0.63      0.66      0.65     55832
# weighted avg       0.93      0.93      0.93     55832
#
# Confusion Matrix
# [[50673  2348]
#  [ 1787  1024]]
# ------------------------------------------------------
# >>>>>>>>>>>>>>  Threat
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90     52825
#            1       0.17      0.56      0.26      3007
#
#     accuracy                           0.82     55832
#    macro avg       0.57      0.70      0.58     55832
# weighted avg       0.93      0.82      0.87     55832
#
# Confusion Matrix
# [[44301  8524]
#  [ 1309  1698]]
# ------------------------------------------------------
# GaussianNB:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95     52825
#            1       0.28      0.37      0.32      3007
#
#     accuracy                           0.92     55832
#    macro avg       0.62      0.66      0.64     55832
# weighted avg       0.93      0.92      0.92     55832
#
# Confusion Matrix
# [[49990  2835]
#  [ 1887  1120]]
# ------------------------------------------------------
# >>>>>>>>>>>>>>  Insult
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.87     55668
#            1       0.01      0.86      0.02       164
#
#     accuracy                           0.78     55832
#    macro avg       0.51      0.82      0.45     55832
# weighted avg       1.00      0.78      0.87     55832
#
# Confusion Matrix
# [[43250 12418]
#  [   23   141]]
# ------------------------------------------------------
# GaussianNB:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     55668
#            1       0.04      0.32      0.08       164
#
#     accuracy                           0.98     55832
#    macro avg       0.52      0.65      0.53     55832
# weighted avg       1.00      0.98      0.99     55832
#
# Confusion Matrix
# [[54536  1132]
#  [  112    52]]
# ------------------------------------------------------
# >>>>>>>>>>>>>>  Identity hate
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.90     55335
#            1       0.02      0.46      0.04       497
#
#     accuracy                           0.81     55832
#    macro avg       0.51      0.64      0.47     55832
# weighted avg       0.99      0.81      0.89     55832
#
# Confusion Matrix
# [[45247 10088]
#  [  270   227]]
# ------------------------------------------------------
# GaussianNB:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     55335
#            1       0.12      0.34      0.17       497
#
#     accuracy                           0.97     55832
#    macro avg       0.56      0.66      0.58     55832
# weighted avg       0.99      0.97      0.98     55832
#
# Confusion Matrix
# [[54080  1255]
#  [  330   167]]
# ------------------------------------------------------

# %%
## AVERAGE FINAL F1 SCORES

f1_LR_final = 0
f1_NB_final = 0

for i in range(len(final_f1)):
  f1_LR_final += final_f1[i][0]
  f1_NB_final += final_f1[i][1]

print("Final F1 score LR: ", f1_LR_final/n_classes)
print("Final F1 score NB: ", f1_NB_final/n_classes)
# Out:
# Final F1 score LR:  0.16571803971384222
# Final F1 score NB:  0.23760113307383054

# %% [markdown]
# We will now try to use the best performing model (BernoulliNB) to implement a naive ranking model.

# %% [markdown]
# ## Simplified scoring model

# %%
## FUNCTIONS

def bernoulliClassifier(X_train,Y_train,X_test):
  bn = BernoulliNB()
  bn.fit(X_train, Y_train)
  predictions = bn.predict(X_test)
  prob = bn.predict_proba(X_test)
  return list(predictions), list(prob)

def remove_empty_tokenized_values(data):
  return data.loc[data["comment_tokenize"].str.len() != 0]

# %%
## GET THE TRAINING SET PREDICTIONS

predictions = []
proba = []

for i in range(len(y_train)):
  print(">>>>>>>>>>>>>> ", d[i+1])
  pred, prob = bernoulliClassifier(X_train,y_train[i],X_test)
  predictions.append(pred)
  proba.append(prob)
# Out:
# >>>>>>>>>>>>>>  Toxic
# >>>>>>>>>>>>>>  Severe Toxic
# >>>>>>>>>>>>>>  Obscene
# >>>>>>>>>>>>>>  Threat
# >>>>>>>>>>>>>>  Insult
# >>>>>>>>>>>>>>  Identity hate

# %%
## CLEAN THE COMMENT SET (remove the empty tokenizations so that the sizes match)

comment_test_data = remove_empty_tokenized_values(comment_test_data)

# %%
## GET THE WEIGHTS FOR EVERY CLASS

for i in range(len(y_train)):
  print(">>>>>>>>>>>>>> ", d[i+1])
  w = weights[i]
  print(w[0])
# Out:
# >>>>>>>>>>>>>>  Toxic
# 10
# >>>>>>>>>>>>>>  Severe Toxic
# 1
# >>>>>>>>>>>>>>  Obscene
# 5
# >>>>>>>>>>>>>>  Threat
# 5
# >>>>>>>>>>>>>>  Insult
# 0.3
# >>>>>>>>>>>>>>  Identity hate
# 0.8

# %%
## COMPUTE SCORES BASED ON WEIGHTS

def get_simplified_score(label_tag, probabilities):

  if label_tag[4] == 1: #insult
    score = 9 + probabilities[4][1]
  elif label_tag[5] == 1: #identity hate
    score = 8 + probabilities[5][1]
  elif label_tag[1] == 1: #severe toxic
    score = 7 + probabilities[1][1]
  elif label_tag[2] == 1 or label_tag[3] == 1: #threat or obscene
    score1 = 5 + 2*probabilities[2][1]
    score2 = 5 + 2*probabilities[3][1]
    score = max(score1,score2)
  elif label_tag[0] == 1: # toxic
    score = 5*probabilities[0][1]
  else: #NON toxic
    score = 0

  return score

def get_column_tag(data_result, ex_idx):
  result = []
  for i in range(6):
    result.append(data_result[i][ex_idx])
  return result

# %%
## GET THE SCORES

N = len(comment_test_data["toxic"])
scores = []

for i in range(N):
  s = get_column_tag(predictions, i)
  p = get_column_tag(proba, i)
  scores.append(get_simplified_score(s,p))

# %%
## EXAMPLES

score_list = [195,216,433,28,274]

for i in score_list: 
  print('Scores: {}'.format(round(scores[i],4)).ljust(20) + 'Comment: ' + comment_test_data["comment"].iloc[i])
# Out:
# Scores: 0           Comment: i think the motd is a waste of time
# Scores: 0           Comment: thank god i am an atheist
# Scores: 3.5643      Comment: kevin bravo is a faggot
# Scores: 4.0478      Comment: fuck off you anti semitic cunt
# Scores: 6.9839      Comment: karl tearle is a mop haired twat

# %%
for i in range(500,700): 
  comment = comment_test_data["comment"].iloc[i]
  truncated_comment = (comment[:60] + ' ...') if len(comment) > 60 else comment
  print(str(i) + " " + 'Scores: {}'.format(round(scores[i],4)).ljust(20) + 'Comment: ' + truncated_comment)
# Out:
# 500 Scores: 0           Comment: designation ship types function the introductory table of va ...
# 501 Scores: 0           Comment: interwiki could an admin add de la studio an new interwiki l ...
# 502 Scores: 0           Comment: of course it is more complex than that i would suggest every ...
# 503 Scores: 0           Comment: fjtfbytrhdfshf nbaahjddnnxcxdhdhv h fthcvyd
# 504 Scores: 0           Comment: music is there a name for a fear of musical instruments im s ...
# 505 Scores: 0           Comment: also there is a separate article terrorism in kashmir for th ...
# 506 Scores: 0           Comment: proposed georgia move as a past participant in the discussio ...
# 507 Scores: 0           Comment: wikipedia is for dickshits like you retarded wikpedia is gay
# 508 Scores: 0           Comment: aww it must have been out on its own for a while and caught  ...
# 509 Scores: 0           Comment: i just left some further comments at the ga review it is the ...
# 510 Scores: 0           Comment: frankly i would rather stalk a sloth
# 511 Scores: 0           Comment: a view point of a dark light thinking person global warming  ...
# 512 Scores: 0           Comment: hello to be honest software corporations are not quite in my ...
# 513 Scores: 0           Comment: style background color fffa padding cellpadding style border ...
# 514 Scores: 0           Comment: hey man i really need your help
# 515 Scores: 0           Comment: i see that my wording was vague summerphd and you went with  ...
# 516 Scores: 0           Comment: no idea i can barely speak english
# 517 Scores: 0           Comment: the urantia book says that religion is a unique dimension of ...
# 518 Scores: 0           Comment: that is a bit more coverage than i thought existed alright i ...
# 519 Scores: 0           Comment: i fear i may be doing this wrong trying to leave a comment h ...
# 520 Scores: 0           Comment: i am gay a whack off to ogrish rape
# 521 Scores: 0           Comment: kashmir hi i have reverted your edit persian is neither an o ...
# 522 Scores: 0           Comment: he certainly was the person behind the whole convention and  ...
# 523 Scores: 0           Comment: that is an interesting story unfortunately this is wikipedia ...
# 524 Scores: 0           Comment: please stop if you continue to vandalize pages you will be b ...
# 525 Scores: 0           Comment: wat the heck what the hell is wrong with you next time you v ...
# 526 Scores: 0           Comment: usually pumped about or less by volume of acid
# 527 Scores: 0           Comment: no problem
# 528 Scores: 0           Comment: to cut a bitch
# 529 Scores: 0           Comment: webster has it as a usually unsubstantiated charge or accusa ...
# 530 Scores: 0           Comment: i am a troll of and i think jimbo wales is an idiot and wiki ...
# 531 Scores: 0           Comment: i will be watching to see what you are doing i am not sure w ...
# 532 Scores: 0           Comment: categories for discussion nomination of category baycroft sc ...
# 533 Scores: 0           Comment: it looks good so far some flak is to be expected and our pur ...
# 534 Scores: 0           Comment: assessments are pov as wikipedia editors we should not asses ...
# 535 Scores: 2.9552      Comment: have you not heard the at t guy just had a heart attack and  ...
# 536 Scores: 2.7612      Comment: because the overall aim of the project is worth putting up w ...
# 537 Scores: 0           Comment: omg a text site you can edit lolololol and here is wat i thi ...
# 538 Scores: 0           Comment: india s already being discussed at template talk indian expr ...
# 539 Scores: 0           Comment: wp dyk did you know
# 540 Scores: 0           Comment: dude omg why does it matter it was released in so obviously  ...
# 541 Scores: 0           Comment: foolish nonsense i have never had to do something that stret ...
# 542 Scores: 0           Comment: sockpuppetry investigation closed hi i have closed the sockp ...
# 543 Scores: 0           Comment: just had an initial read through which seems ok good prose a ...
# 544 Scores: 0           Comment: consistency just for the sake of consistency with the projec ...
# 545 Scores: 0           Comment: you obviously do not have to downright deny something to que ...
# 546 Scores: 0           Comment: great work on the changes i will add stuff if i think it is  ...
# 547 Scores: 0           Comment: npov this following section in the article seems very npov t ...
# 548 Scores: 0           Comment: yakushima one definition of insanity is when a person does t ...
# 549 Scores: 0           Comment: this user is a sockpuppet of
# 550 Scores: 0           Comment: new feature in google maps hi blofeld just to let you know h ...
# 551 Scores: 0           Comment: in ernst lubitsch s comedy ninotchka with her last film geor ...
# 552 Scores: 0           Comment: hey i see you are good faith editing korn s ninth studio alb ...
# 553 Scores: 0           Comment: added a dyk nom today
# 554 Scores: 0           Comment: yeah i meant the first and third paragraphs of the neighborh ...
# 555 Scores: 0           Comment: virusandleukaemiainman the article sounds very fascinating b ...
# 556 Scores: 0           Comment: wikiproject anime and manga class stub importance low
# 557 Scores: 0           Comment: subtropical storms ace thanks for the information it is anno ...
# 558 Scores: 0           Comment: rm re hat h t
# 559 Scores: 0           Comment: only the wailers is mentioned to be the artist yet the cover ...
# 560 Scores: 0           Comment: frankly in most cases it is too much trouble to worry about  ...
# 561 Scores: 0           Comment: sock help hello i see that you blocked as a sock is from the ...
# 562 Scores: 0           Comment: but there is nothing wrong with putting in the player who wo ...
# 563 Scores: 0           Comment: man this does look like crap i vote to put older colors on t ...
# 564 Scores: 0           Comment: i will give you assurance that i do not have hatred for you  ...
# 565 Scores: 0           Comment: you have got mail check it
# 566 Scores: 0           Comment: bzzt seeking anything on teh jimbo s page is always about sh ...
# 567 Scores: 2.6431      Comment: dr marmilade you are a bastard pro assad you are wedge assad ...
# 568 Scores: 0           Comment: oppose the title should be iranian persians is nonsense the  ...
# 569 Scores: 0           Comment: flc family guy season i see you failed the nomination anyway ...
# 570 Scores: 0           Comment: child discipline are the details of the various implements u ...
# 571 Scores: 0           Comment: uaa holding pen question had a questions about the holding p ...
# 572 Scores: 0           Comment: are you fucking kidding meryulong
# 573 Scores: 0           Comment: precice meaning of the latin post scriptum was listed in the ...
# 574 Scores: 0           Comment: thank you so much for the encouragement i would surely be ca ...
# 575 Scores: 0           Comment: this article makes it clear that there is currently a contro ...
# 576 Scores: 0           Comment: reply to all this shit yous lots have been writing omg what  ...
# 577 Scores: 0           Comment: p s but tell you what i collapsed my entire user page and wi ...
# 578 Scores: 0           Comment: err to add to what i said is http ww religioustolerance org  ...
# 579 Scores: 0           Comment: wrong coordinates wikipedia is my favorite source of informa ...
# 580 Scores: 4.3525      Comment: this account is a sock puppet of dantherocker
# 581 Scores: 0           Comment: exactly this is not about dc she is embarking on a solo care ...
# 582 Scores: 0           Comment: yeah that is what my original clarify was really about so i  ...
# 583 Scores: 0           Comment: lighthouse i was pointed in the direction to move it to ligh ...
# 584 Scores: 0           Comment: what looks like the egg fleet appeared in the trailer the eg ...
# 585 Scores: 0           Comment: deleted images as not screenshots you deleted a number of my ...
# 586 Scores: 0           Comment: fuck you you like angelique carrington and tamara harrington ...
# 587 Scores: 0           Comment: to q here you said to q but i do not think it got there whil ...
# 588 Scores: 0           Comment: and you are guy mother fucker
# 589 Scores: 0           Comment: improvement drive the article grameen bank is currently nomi ...
# 590 Scores: 0           Comment: ulu panah is unknow to me must be refered to ulu pahang old  ...
# 591 Scores: 0           Comment: this article was nominated for deletion on june the consensu ...
# 592 Scores: 0           Comment: i seem to be jumping into a nest of vipers but devanampriya  ...
# 593 Scores: 0           Comment: this should have been an apology for your grotesquely inappr ...
# 594 Scores: 0           Comment: thank you for experimenting with the page javanese on wikipe ...
# 595 Scores: 0           Comment: memphis queen dear billcj you have deleted the link to memph ...
# 596 Scores: 0           Comment: cost of publication i was wondering if the cost of keeping u ...
# 597 Scores: 0           Comment: kober can you translate just couple of reactions by the geor ...
# 598 Scores: 4.54        Comment: redirect talk northsouth divide in the united kingdom
# 599 Scores: 0           Comment: since the article has been split i moved the links on contro ...
# 600 Scores: 0           Comment: i tried adding a in fr discussion wikipdia wpcleaner but no  ...
# 601 Scores: 0           Comment: fuck you butt nigger
# 602 Scores: 0           Comment: ryan boe is a queer this is the truth hes a big ol gay bag t ...
# 603 Scores: 0           Comment: the article does not say that canada has a two party system  ...
# 604 Scores: 0           Comment: seriously i can see the reasoning for some of these being on ...
# 605 Scores: 0           Comment: i think i am outta here you should be ashamed of yourself
# 606 Scores: 0           Comment: o k then poll ended by the way i propose starting a new talk ...
# 607 Scores: 0           Comment: i note that vipernerd s bad faith edit warring continues una ...
# 608 Scores: 0           Comment: i still am annoyed at you blockig me and dmacks is an idiot
# 609 Scores: 0           Comment: cultural references where is this section it is included in  ...
# 610 Scores: 0           Comment: since no one else has weighed in my ideas first the change s ...
# 611 Scores: 0           Comment: please stop if you continue to vandalize wikipedia you will  ...
# 612 Scores: 0           Comment: shut up please this consensus is over
# 613 Scores: 0           Comment: this article has the exact same controversy section as this  ...
# 614 Scores: 0           Comment: thank you for explaining
# 615 Scores: 0           Comment: kamikaze museum have you read the references they are saying ...
# 616 Scores: 0           Comment: july utc i would suggest ignoring kgartm as he appears to ha ...
# 617 Scores: 0           Comment: you wrote this kid is a well known birmingham athlete so i a ...
# 618 Scores: 0           Comment: oh my dan the viking is roaming the shores of english wikipe ...
# 619 Scores: 0           Comment: at least as used in the us single payer means that there is  ...
# 620 Scores: 0           Comment: are you threatening me to block me for no reason you are a f ...
# 621 Scores: 0           Comment: tom good to see you again and glad your edit is on one of th ...
# 622 Scores: 0           Comment: race i take it from the mention that the invaders are siniti ...
# 623 Scores: 4.9197      Comment: gianmarco rossini
# 624 Scores: 0           Comment: major inconsistency what time did ccr actually start playing ...
# 625 Scores: 0           Comment: different parties
# 626 Scores: 0           Comment: igor girkin says a lot of crazy things like ukraine would at ...
# 627 Scores: 0           Comment: the lead refs were just an error and have now been fixed the ...
# 628 Scores: 4.5526      Comment: noses i blow my nose in them
# 629 Scores: 0           Comment: put it very well i suspect that many like myself just do not ...
# 630 Scores: 0           Comment: d can you tell that d died of drug overdose on december and  ...
# 631 Scores: 0           Comment: i wonder if it would not be a better idea to focus on bite s ...
# 632 Scores: 0           Comment: list of pseudoscientific theories could you please restore t ...
# 633 Scores: 0           Comment: the article does not claim the organisation as a whole parti ...
# 634 Scores: 0           Comment: currently he and his colleagues from his newspaper taz are p ...
# 635 Scores: 0           Comment: on the fish draft see what are now refs and i thought it was ...
# 636 Scores: 0           Comment: fuck islam fuck saud arabia
# 637 Scores: 0           Comment: thank you seksen for your intervention and yes you are right ...
# 638 Scores: 0           Comment: hello i am new here well not really new to wikipedia but new ...
# 639 Scores: 0           Comment: i stopped checking for close paraprhasing copyright violatio ...
# 640 Scores: 0           Comment: is blood type really necessary that seems like tmi to me esp ...
# 641 Scores: 0           Comment: delete my userpage and talkpage editnotice please deleted my ...
# 642 Scores: 0           Comment: replay review i added an objection to deletion on the talk p ...
# 643 Scores: 0           Comment: political section just deleted a weasel worded political sec ...
# 644 Scores: 0           Comment: hi bluemask i am not feeling well today i am very insulted w ...
# 645 Scores: 0           Comment: agree with darouet one temporary decision now does not negat ...
# 646 Scores: 0           Comment: use jimbo wales ok sorry but it was kind of funny
# 647 Scores: 0           Comment: nick has mentioned shermer s book why people believe wierd t ...
# 648 Scores: 0           Comment: adoption thanks for your clear eyed constructive criticism o ...
# 649 Scores: 0           Comment: utterly utterly tiny insignificant anal retentive thing but  ...
# 650 Scores: 0           Comment: i think the origin of sagging has his roots in that human st ...
# 651 Scores: 4.7811      Comment: why una mierda tu puta madre
# 652 Scores: 0           Comment: external links since most have no other article here seems t ...
# 653 Scores: 0           Comment: wow wnt a damn kookie nigga
# 654 Scores: 0           Comment: unspecified source for image channingtatum jpg thanks for up ...
# 655 Scores: 0           Comment: list out of date moved from article to here through issues h ...
# 656 Scores: 0           Comment: vast majority of mizrahi jews never heard of zatar before th ...
# 657 Scores: 0           Comment: no i am not i am observing it from the information provided  ...
# 658 Scores: 0           Comment: redirect talk th rifle division soviet union
# 659 Scores: 0           Comment: serial killer would kenneth mcduff classify as a serial kill ...
# 660 Scores: 0           Comment: race and intelligence i have had a running argument on the t ...
# 661 Scores: 0           Comment: this is what caused and or made concrete the schism not the  ...
# 662 Scores: 0           Comment: that is your opinion i am sure that the criticism article wa ...
# 663 Scores: 0           Comment: february utc the most common and widespread usage whether it ...
# 664 Scores: 0           Comment: prophylaxis is bad i do not think we should leap to protecti ...
# 665 Scores: 0           Comment: thanks for experimenting with wikipedia your test worked and ...
# 666 Scores: 0           Comment: and are easy to find
# 667 Scores: 0           Comment: yeah but incase i screw up i have a page that i can fix with ...
# 668 Scores: 0           Comment: thanks for making those changes hawkeye they look good i am  ...
# 669 Scores: 3.6228      Comment: visibly sick how so vomiting clammy hands pale complexion se ...
# 670 Scores: 0           Comment: thank you for your offer however situation seems to have qui ...
# 671 Scores: 0           Comment: israeli names for santa claus i have been asked to provide c ...
# 672 Scores: 0           Comment: november utc every single edit today has been riddled with m ...
# 673 Scores: 0           Comment: hurricane julia wikipage i made hurricane julia a wikipagem  ...
# 674 Scores: 0           Comment: or else from an animal dealer
# 675 Scores: 0           Comment: are you talking about the quotes from these sources http ww  ...
# 676 Scores: 0           Comment: from japanese wikipedia
# 677 Scores: 0           Comment: as his fourth clerk justice thomas has hired christopher lan ...
# 678 Scores: 0           Comment: i think it best to leave the election tables as they will ap ...
# 679 Scores: 3.7005      Comment: block evading ip sockpuppet
# 680 Scores: 0           Comment: i m pretty sure this is a joke the other books for sale are  ...
# 681 Scores: 0           Comment: support to get rid of another of the vestiges of badsites st ...
# 682 Scores: 0           Comment: dyk for white capped albatross class messagebox talk on marc ...
# 683 Scores: 0           Comment: i am pleased that my efforts yesterday have prompted such po ...
# 684 Scores: 0           Comment: ellie i am looking into the issues on susan polgar and paul  ...
# 685 Scores: 0           Comment: thanks so far on my second point which is more of a personal ...
# 686 Scores: 0           Comment: i am working on a re write but i am finding this very challe ...
# 687 Scores: 0           Comment: thanks style border px solid gray background color lightblue ...
# 688 Scores: 0           Comment: what the hell please start a gar and remove that nonsense
# 689 Scores: 0           Comment: in response to your feedback welcome to wikipedia thank you  ...
# 690 Scores: 0           Comment: personal life there is no mention of cheryl cole s sexual or ...
# 691 Scores: 0           Comment: i hope you get the swine flu wallah bro move out of ur moms  ...
# 692 Scores: 0           Comment: psr b hello i have been involved in editing psr b and would  ...
# 693 Scores: 0           Comment: no we can t not technically feasible not what this map was c ...
# 694 Scores: 0           Comment: ech you silly mensans you have iq points to spare
# 695 Scores: 0           Comment: is he really british or british born american july utc
# 696 Scores: 0           Comment: extra territorium jus dicenti impune non paretur see you lat ...
# 697 Scores: 0           Comment: a kitten for you you ruin my life
# 698 Scores: 0           Comment: barnstar for you style border px solid gray background color ...
# 699 Scores: 0           Comment: the article you deleted bwilkins talk contribs deleted alexa ...
